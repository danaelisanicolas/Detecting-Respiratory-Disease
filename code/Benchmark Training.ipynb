# %% [markdown]
# Basic CNN Training by using a basic spectogram

# %%
import librosa as lb
from librosa.display import waveplot
from librosa.display import specshow

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import matplotlib.pyplot as plt

from os import listdir
from os.path import isfile, join

# %%
#create images using librosa spectogram
def convert_to_spec_image(file):
    ''' 
        Converts audio file to spec image
        Input file includes path
        Saves the file to a png image in the same directory
    '''
    y, sr = lb.load(file)

    #Plot signal in
    plt.figure(figsize=(10,3))
    src_ft = lb.stft(y)
    src_db = lb.amplitude_to_db(abs(src_ft))
    specshow(src_db, sr=sr, x_axis='time', y_axis='hz')  
    plt.ylim(0, 5000)
    
    filename_img = file.split('.wav')[0]
    plt.savefig(filename_img + '.png')
    plt.close()

# %%
def is_wav(filename):
    '''
        Checks if files are .wav files
        Utility tool in converting wav to png files
    '''
    return filename.split('.')[1] == 'wav'

# %%
#test the function
test_file = '../data/Respiratory_Files/train_test_split/train/Bronchiectasis/111_1b2_Tc_sc_Meditron.wav'

convert_to_spec_image(test_file)

# %%
dis_cat = ['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'LRTI', 'Pneumonia', 'URTI']

# %%
train_loc = '../data/Respiratory_Files/train_test_split/train/'
test_loc = '../data/Respiratory_Files/train_test_split/val/'

# %%
#Convert all wav to png in TRAIN folder
for cat in dis_cat:
    files = [f for f in listdir(train_loc + cat) if isfile(join(train_loc + cat, f))]
    for f in files:
        if is_wav(f):
            convert_to_spec_image(train_loc + cat + '/' + f)

# %%
#Convert all wav to png in TEST folder
for cat in dis_cat:
    files = [f for f in listdir(test_loc + cat) if isfile(join(test_loc + cat, f))]
    for f in files:
        if is_wav(f):
            convert_to_spec_image(test_loc + cat + '/' + f)

# %%
trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory=train_loc, target_size=(224,224))
tsdata = ImageDataGenerator()
testdata = tsdata.flow_from_directory(directory=test_loc, target_size=(224,224))
# Out:
# Found 732 images belonging to 8 classes.
# Found 188 images belonging to 8 classes.

# %%
vgg16 = VGG16(weights='imagenet')
vgg16.summary()

x  = vgg16.get_layer('fc2').output
prediction = Dense(8, activation='softmax', name='predictions')(x)

model = Model(inputs=vgg16.input, outputs=prediction)
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in model.layers:
    layer.trainable = False

for layer in model.layers[-8:]:
    layer.trainable = True
    print("Layer '%s' is trainable" % layer.name)
# Out:
# Layer 'block5_conv1' is trainable
# Layer 'block5_conv2' is trainable
# Layer 'block5_conv3' is trainable
# Layer 'block5_pool' is trainable
# Layer 'flatten' is trainable
# Layer 'fc1' is trainable
# Layer 'fc2' is trainable
# Layer 'predictions' is trainable

# %%
opt = Adam(lr=0.00001)
model.compile(optimizer=opt, loss=categorical_crossentropy, metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 8)                 32776
# =================================================================
# Total params: 134,293,320
# Trainable params: 126,658,056
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint("vgg16_res.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')

# %%
hist = model.fit_generator(steps_per_epoch=5,generator=traindata, validation_data= testdata, validation_steps=5,epochs=50,callbacks=[checkpoint,early])
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 5 steps
# Epoch 1/50
# 4/5 [=======================>......] - ETA: 14s - loss: 1.9621 - accuracy: 0.6484
# Epoch 00001: val_accuracy improved from -inf to 0.80625, saving model to vgg16_res.h5
# 5/5 [==============================] - 120s 24s/step - loss: 1.8881 - accuracy: 0.6750 - val_loss: 1.2581 - val_accuracy: 0.8062
# Epoch 2/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.8702 - accuracy: 0.8065
# Epoch 00002: val_accuracy improved from 0.80625 to 0.86250, saving model to vgg16_res.h5
# 5/5 [==============================] - 111s 22s/step - loss: 0.7712 - accuracy: 0.8205 - val_loss: 0.5125 - val_accuracy: 0.8625
# Epoch 3/50
# 4/5 [=======================>......] - ETA: 13s - loss: 0.4864 - accuracy: 0.8438
# Epoch 00003: val_accuracy did not improve from 0.86250
# 5/5 [==============================] - 115s 23s/step - loss: 0.4633 - accuracy: 0.8562 - val_loss: 0.4161 - val_accuracy: 0.8625
# Epoch 4/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.3969 - accuracy: 0.8906
# Epoch 00004: val_accuracy improved from 0.86250 to 0.88750, saving model to vgg16_res.h5
# 5/5 [==============================] - 108s 22s/step - loss: 0.4033 - accuracy: 0.8846 - val_loss: 0.4120 - val_accuracy: 0.8875
# Epoch 5/50
# 4/5 [=======================>......] - ETA: 14s - loss: 0.5917 - accuracy: 0.8125
# Epoch 00005: val_accuracy did not improve from 0.88750
# 5/5 [==============================] - 126s 25s/step - loss: 0.5830 - accuracy: 0.8062 - val_loss: 0.3553 - val_accuracy: 0.8813
# Epoch 6/50
# 4/5 [=======================>......] - ETA: 15s - loss: 0.4215 - accuracy: 0.8672
# Epoch 00006: val_accuracy did not improve from 0.88750
# 5/5 [==============================] - 128s 26s/step - loss: 0.3911 - accuracy: 0.8750 - val_loss: 0.3756 - val_accuracy: 0.8625
# Epoch 7/50
# 4/5 [=======================>......] - ETA: 13s - loss: 0.4083 - accuracy: 0.8516
# Epoch 00007: val_accuracy improved from 0.88750 to 0.90000, saving model to vgg16_res.h5
# 5/5 [==============================] - 118s 24s/step - loss: 0.4014 - accuracy: 0.8500 - val_loss: 0.3037 - val_accuracy: 0.9000
# Epoch 8/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.2122 - accuracy: 0.9062
# Epoch 00008: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 116s 23s/step - loss: 0.2400 - accuracy: 0.9062 - val_loss: 0.3117 - val_accuracy: 0.8938
# Epoch 9/50
# 4/5 [=======================>......] - ETA: 14s - loss: 0.3600 - accuracy: 0.8906
# Epoch 00009: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 120s 24s/step - loss: 0.3655 - accuracy: 0.8813 - val_loss: 0.3012 - val_accuracy: 0.8875
# Epoch 10/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.2117 - accuracy: 0.9355
# Epoch 00010: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 111s 22s/step - loss: 0.1956 - accuracy: 0.9487 - val_loss: 0.3664 - val_accuracy: 0.8750
# Epoch 11/50
# 4/5 [=======================>......] - ETA: 13s - loss: 0.2730 - accuracy: 0.9062
# Epoch 00011: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 111s 22s/step - loss: 0.2938 - accuracy: 0.8938 - val_loss: 0.3681 - val_accuracy: 0.8875
# Epoch 12/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.2230 - accuracy: 0.9219
# Epoch 00012: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 115s 23s/step - loss: 0.2121 - accuracy: 0.9250 - val_loss: 0.3386 - val_accuracy: 0.8875
# Epoch 13/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.3748 - accuracy: 0.8548
# Epoch 00013: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 115s 23s/step - loss: 0.3649 - accuracy: 0.8526 - val_loss: 0.3555 - val_accuracy: 0.8562
# Epoch 14/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.3938 - accuracy: 0.8828
# Epoch 00014: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 108s 22s/step - loss: 0.4197 - accuracy: 0.8813 - val_loss: 0.3939 - val_accuracy: 0.8875
# Epoch 15/50
# 4/5 [=======================>......] - ETA: 13s - loss: 0.1933 - accuracy: 0.8984
# Epoch 00015: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 116s 23s/step - loss: 0.1684 - accuracy: 0.9125 - val_loss: 0.3153 - val_accuracy: 0.8938
# Epoch 16/50
# 4/5 [=======================>......] - ETA: 11s - loss: 0.2592 - accuracy: 0.9062
# Epoch 00016: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 97s 19s/step - loss: 0.2372 - accuracy: 0.9062 - val_loss: 0.3538 - val_accuracy: 0.8687
# Epoch 17/50
# 4/5 [=======================>......] - ETA: 11s - loss: 0.1904 - accuracy: 0.9141
# Epoch 00017: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 107s 21s/step - loss: 0.2476 - accuracy: 0.9000 - val_loss: 0.3427 - val_accuracy: 0.8875
# Epoch 18/50
# 4/5 [=======================>......] - ETA: 13s - loss: 0.3351 - accuracy: 0.8594
# Epoch 00018: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 117s 23s/step - loss: 0.2774 - accuracy: 0.8813 - val_loss: 0.3289 - val_accuracy: 0.8750
# Epoch 19/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.1756 - accuracy: 0.9274
# Epoch 00019: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 140s 28s/step - loss: 0.2472 - accuracy: 0.9103 - val_loss: 0.3457 - val_accuracy: 0.8813
# Epoch 20/50
# 4/5 [=======================>......] - ETA: 13s - loss: 0.3074 - accuracy: 0.8828
# Epoch 00020: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 120s 24s/step - loss: 0.2594 - accuracy: 0.9000 - val_loss: 0.3424 - val_accuracy: 0.8750
# Epoch 21/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.2803 - accuracy: 0.9274
# Epoch 00021: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 113s 23s/step - loss: 0.2624 - accuracy: 0.9231 - val_loss: 0.3362 - val_accuracy: 0.9000
# Epoch 22/50
# 4/5 [=======================>......] - ETA: 15s - loss: 0.2968 - accuracy: 0.9141
# Epoch 00022: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 130s 26s/step - loss: 0.2682 - accuracy: 0.9250 - val_loss: 0.3492 - val_accuracy: 0.8687
# Epoch 23/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.2405 - accuracy: 0.9219
# Epoch 00023: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 121s 24s/step - loss: 0.2178 - accuracy: 0.9250 - val_loss: 0.3218 - val_accuracy: 0.8750
# Epoch 24/50
# 4/5 [=======================>......] - ETA: 14s - loss: 0.1722 - accuracy: 0.9141
# Epoch 00024: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 121s 24s/step - loss: 0.1598 - accuracy: 0.9250 - val_loss: 0.4082 - val_accuracy: 0.8938
# Epoch 25/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.1336 - accuracy: 0.9453
# Epoch 00025: val_accuracy did not improve from 0.90000
# 5/5 [==============================] - 110s 22s/step - loss: 0.1494 - accuracy: 0.9438 - val_loss: 0.2930 - val_accuracy: 0.9000
# Epoch 26/50
# 4/5 [=======================>......] - ETA: 11s - loss: 0.1409 - accuracy: 0.9355
# Epoch 00026: val_accuracy improved from 0.90000 to 0.91875, saving model to vgg16_res.h5
# 5/5 [==============================] - 106s 21s/step - loss: 0.1855 - accuracy: 0.9295 - val_loss: 0.3316 - val_accuracy: 0.9187
# Epoch 27/50
# 4/5 [=======================>......] - ETA: 13s - loss: 0.0281 - accuracy: 0.9922
# Epoch 00027: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 103s 21s/step - loss: 0.0568 - accuracy: 0.9812 - val_loss: 0.4136 - val_accuracy: 0.9187
# Epoch 28/50
# 4/5 [=======================>......] - ETA: 11s - loss: 0.1123 - accuracy: 0.9609
# Epoch 00028: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 105s 21s/step - loss: 0.0961 - accuracy: 0.9688 - val_loss: 0.4984 - val_accuracy: 0.9000
# Epoch 29/50
# 4/5 [=======================>......] - ETA: 14s - loss: 0.1620 - accuracy: 0.9297
# Epoch 00029: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 129s 26s/step - loss: 0.1321 - accuracy: 0.9438 - val_loss: 0.3151 - val_accuracy: 0.9187
# Epoch 30/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.1670 - accuracy: 0.9531
# Epoch 00030: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 107s 21s/step - loss: 0.1589 - accuracy: 0.9500 - val_loss: 0.3332 - val_accuracy: 0.9000
# Epoch 31/50
# 4/5 [=======================>......] - ETA: 14s - loss: 0.1224 - accuracy: 0.9531
# Epoch 00031: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 122s 24s/step - loss: 0.1197 - accuracy: 0.9563 - val_loss: 0.3436 - val_accuracy: 0.9000
# Epoch 32/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.1563 - accuracy: 0.9453
# Epoch 00032: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 104s 21s/step - loss: 0.1807 - accuracy: 0.9375 - val_loss: 0.5008 - val_accuracy: 0.9062
# Epoch 33/50
# 4/5 [=======================>......] - ETA: 10s - loss: 0.0664 - accuracy: 0.9758
# Epoch 00033: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 93s 19s/step - loss: 0.2330 - accuracy: 0.9423 - val_loss: 0.5527 - val_accuracy: 0.8625
# Epoch 34/50
# 4/5 [=======================>......] - ETA: 11s - loss: 0.2360 - accuracy: 0.9375
# Epoch 00034: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 101s 20s/step - loss: 0.2332 - accuracy: 0.9312 - val_loss: 0.3674 - val_accuracy: 0.8938
# Epoch 35/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.1040 - accuracy: 0.9516
# Epoch 00035: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 120s 24s/step - loss: 0.1648 - accuracy: 0.9231 - val_loss: 0.4480 - val_accuracy: 0.8875
# Epoch 36/50
# 4/5 [=======================>......] - ETA: 11s - loss: 0.1548 - accuracy: 0.9297
# Epoch 00036: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 104s 21s/step - loss: 0.1336 - accuracy: 0.9375 - val_loss: 0.5097 - val_accuracy: 0.8813
# Epoch 37/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.0891 - accuracy: 0.9609
# Epoch 00037: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 104s 21s/step - loss: 0.0990 - accuracy: 0.9563 - val_loss: 0.4167 - val_accuracy: 0.9000
# Epoch 38/50
# 4/5 [=======================>......] - ETA: 11s - loss: 0.1474 - accuracy: 0.9688
# Epoch 00038: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 103s 21s/step - loss: 0.1367 - accuracy: 0.9688 - val_loss: 0.4283 - val_accuracy: 0.9062
# Epoch 39/50
# 4/5 [=======================>......] - ETA: 10s - loss: 0.0415 - accuracy: 0.9844
# Epoch 00039: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 101s 20s/step - loss: 0.0403 - accuracy: 0.9875 - val_loss: 0.5768 - val_accuracy: 0.9062
# Epoch 40/50
# 4/5 [=======================>......] - ETA: 11s - loss: 0.1173 - accuracy: 0.9766
# Epoch 00040: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 113s 23s/step - loss: 0.1189 - accuracy: 0.9688 - val_loss: 0.5384 - val_accuracy: 0.9062
# Epoch 41/50
# 4/5 [=======================>......] - ETA: 13s - loss: 0.0523 - accuracy: 0.9766
# Epoch 00041: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 111s 22s/step - loss: 0.0812 - accuracy: 0.9625 - val_loss: 0.6747 - val_accuracy: 0.9187
# Epoch 42/50
# 4/5 [=======================>......] - ETA: 13s - loss: 0.0827 - accuracy: 0.9688
# Epoch 00042: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 116s 23s/step - loss: 0.0942 - accuracy: 0.9688 - val_loss: 0.4645 - val_accuracy: 0.8938
# Epoch 43/50
# 4/5 [=======================>......] - ETA: 14s - loss: 0.1692 - accuracy: 0.9531
# Epoch 00043: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 118s 24s/step - loss: 0.1850 - accuracy: 0.9438 - val_loss: 0.4373 - val_accuracy: 0.8750
# Epoch 44/50
# 4/5 [=======================>......] - ETA: 14s - loss: 0.1390 - accuracy: 0.9531
# Epoch 00044: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 115s 23s/step - loss: 0.1214 - accuracy: 0.9625 - val_loss: 1.1999 - val_accuracy: 0.8625
# Epoch 45/50
# 4/5 [=======================>......] - ETA: 12s - loss: 0.4913 - accuracy: 0.8828
# Epoch 00045: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 105s 21s/step - loss: 0.4379 - accuracy: 0.8875 - val_loss: 0.5959 - val_accuracy: 0.8687
# Epoch 46/50
# 4/5 [=======================>......] - ETA: 11s - loss: 0.2253 - accuracy: 0.9297
# Epoch 00046: val_accuracy did not improve from 0.91875
# 5/5 [==============================] - 104s 21s/step - loss: 0.2181 - accuracy: 0.9312 - val_loss: 0.6584 - val_accuracy: 0.8938
# Epoch 00046: early stopping
